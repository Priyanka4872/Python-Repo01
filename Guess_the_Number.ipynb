# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka4872/Python-Repo01/blob/main/Guess_the_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
RaVal=random.randint(0,100)
Num=int(input("Enter guessed Number:"))
if Num==RaVal:
  print("You Guessed it Right!...",RalVal)
elif Num>RaVal:
  print("Guessed Number",Num,"is Greater than the target number.....Try Again!")
else:
  print("Guessed Number",Num,"is Smaller than the target number.....Try Again!")
# Out:
# Enter guessed Number:78
# Guessed Number 78 is Greater than the target number.....Try Again!
