# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanka4872/Python-Repo01/blob/main/hcf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input())
b=int(input())
if a<b:
  small=a
else:
  small=b
  while(True):
    if a%small==0 and b%small==0:
      print("HCF is:",small)
      break
    else:
          small=small-1
# Out:
# 21
# 12
# HCF is: 3
